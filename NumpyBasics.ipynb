# %% [markdown]
# Basics

# %%
import numpy as np

# %%
arr_1D= np.array([1,2,3,4,5])
print("1D Array:", arr_1D)
# Out:
# 1D Array: [1 2 3 4 5]

# %%
print("Multiplication by 2:", arr_1D * 2)
# Out:
# Multiplication by 2: [ 2  4  6  8 10]

# %%
print("zero matrix:", np.zeros((3, 4)))

print("one matrix:", np.ones((2, 5)))

print("Constant matrix:", np.full((3, 3), 7))

print("Random matrix:", np.random.rand(2, 3))

print("sequence array:", np.arange(0, 10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print("zero matrix:", np.zeros(3, 4))
#       3 print("one matrix:", np.ones((2, 5)))
#       5 print("Constant matrix:", np.full((3, 3), 7))
#
# TypeError: Cannot interpret '4' as a data type

# %% [markdown]
# #Properties Of Arrays

# %%
arr= np.array([[1,2,3],[4,5,6]])
print("Array Properties:")
print("Shape:", arr.shape)
print("Data Type:", arr.dtype)
print("Size:", arr.size)
print("Number of Dimensions:", arr.ndim)
print("Transpose:\n", arr.T)
# Out:
# Array Properties:
# Shape: (2, 3)
# Data Type: int64
# Size: 6
# Number of Dimensions: 2
# Transpose:
#  [[1 4]
#  [2 5]
#  [3 6]]
